# %%
import mlflow

# %%
import os

# %%
# tracking_server_arn =  os.environ["TRACKING_SERVER_ARN"]
tracking_server_arn = 'arn:aws:sagemaker:us-east-1:975049948583:mlflow-tracking-server/mlflow-tracking-server'

# %%
mlflow.set_tracking_uri(tracking_server_arn)
mlflow.set_experiment("01_preprocessing_kmeans")
# Out:
# 2025/07/06 22:20:06 INFO mlflow.tracking.fluent: Experiment with name '01_preprocessing_kmeans' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://swo-ngoctran-public/mlflow-tracking/1', creation_time=1751840406827, experiment_id='1', last_update_time=1751840406827, lifecycle_stage='active', name='01_preprocessing_kmeans', tags={}>

# %%
mlflow.__version__
# Out:
# '2.21.3'

# %%
tracking_server_url = "https://t-shqyllgofmce.us-east-1.experiments.sagemaker.aws/"

# %%
mlflow.set_tracking_uri(tracking_server_url)

# %%
mlflow.set_experiment("01_preprocessing_kmeans")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mlflow.set_experiment("01_preprocessing_kmeans")
#
# File /opt/conda/lib/python3.12/site-packages/mlflow/tracking/fluent.py:157, in set_experiment(experiment_name, experiment_id)
#     155 with _experiment_lock:
#     156     if experiment_id is None:
# --> 157         experiment = client.get_experiment_by_name(experiment_name)
#     158         if not experiment:
#     159             try:
#
# File /opt/conda/lib/python3.12/site-packages/mlflow/tracking/client.py:1698, in MlflowClient.get_experiment_by_name(self, name)
#    1666 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1667     """Retrieve an experiment by experiment name from the backend store
#    1668
#    1669     Args:
#    (...)
#    1696         Lifecycle_stage: active
#    1697     """
# -> 1698     return self._tracking_client.get_experiment_by_name(name)
#
# File /opt/conda/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:586, in TrackingServiceClient.get_experiment_by_name(self, name)
#     578 def get_experiment_by_name(self, name):
#     579     """
#     580     Args:
#     581         name: The experiment name.
#    (...)
#     584         :py:class:`mlflow.entities.Experiment`
#     585     """
# --> 586     return self.store.get_experiment_by_name(name)
#
# File /opt/conda/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:641, in RestStore.get_experiment_by_name(self, experiment_name)
#     639 try:
#     640     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 641     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     642     return Experiment.from_proto(response_proto.experiment)
#     643 except MlflowException as e:
#
# File /opt/conda/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:90, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      88     endpoint, method = _METHOD_TO_INFO[api]
#      89 response_proto = api.Response()
# ---> 90 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File /opt/conda/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:392, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     389     call_kwargs["json"] = json_body
#     390     response = http_request(**call_kwargs)
# --> 392 response = verify_rest_response(response, endpoint)
#     393 response_to_parse = response.text
#     394 js_dict = json.loads(response_to_parse)
#
# File /opt/conda/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:255, in verify_rest_response(response, endpoint)
#     250     else:
#     251         base_msg = (
#     252             f"API request to endpoint {endpoint} "
#     253             f"failed with error code {response.status_code} != 200"
#     254         )
# --> 255         raise MlflowException(
#     256             f"{base_msg}. Response body: '{response.text}'",
#     257             error_code=get_error_code(response.status_code),
#     258         )
#     260 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     261 # response
#     262 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/experiments/get-by-name failed with error code 400 != 200. Response body: 'Missing Tracking Server ARN'
