# %%
import pandas as pd
import numpy as np
import sys
import gc

import os
sys.path.append(os.path.abspath(".."))

# %%
import s3fs
from typing import List

from utils.common import *
from config.params import *
from preprocessing.transform import transform, tracking_transforming_input
from preprocessing.intervals import get_interval_from_transformed

# %%
from preprocessing.prepare_clustering_data import *
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
from training.models import *
from training.visualize import *

# %%
from pyarrow.dataset import field

# %%
import sagemaker
from sagemaker import get_execution_role

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# get the lastest saved data from mlflow run
import mlflow
from mlflow.tracking import MlflowClient

# %%
from sklearn.cluster import KMeans
from datetime import datetime
from pathlib import Path

# %%
import sagemaker
import boto3
from sagemaker.estimator import Estimator
from sagemaker.inputs import TrainingInput

# %%
from io import StringIO

# %%
from sagemaker.model import Model
from sagemaker.transformer import Transformer

# %%
client = MlflowClient()

# %%
# Define session, role, and region so we can
# perform any SageMaker tasks we need
sagemaker_session = sagemaker.Session()
role = get_execution_role()
region = sagemaker_session.boto_region_name

# %%
# Provide the ARN of the tracking server that you want to track your training job with
tracking_server_arn = 'arn:aws:sagemaker:ap-southeast-1:771463264346:mlflow-tracking-server/mlflow-RCF-server'

# %%
mlflow.set_tracking_uri(tracking_server_arn)

# %%
experiment_name = "4. Training RCF Model"
mlflow.set_experiment(experiment_name)
# Out:
# <Experiment: artifact_location='s3://s3-assetcare-bucket/mlflow_server/20', creation_time=1745547487760, experiment_id='20', last_update_time=1745547487760, lifecycle_stage='active', name='4. Training RCF Model', tags={}>

# %% [markdown]
# ### functions

# %%
def get_value(run_id, keys):
    run = mlflow.get_run(run_id)

    # Lấy toàn bộ params
    params = run.data.params
    # print(params)
    
    # Lấy giá trị cụ thể, ví dụ: cluster_id
    filepath = [params.get(key) for key in keys]
    return filepath

# %%
def detect_value_intervals(df: pd.DataFrame) -> pd.DataFrame:
    """
    Parameters:
    - df: DataFrame with 'value' and 'time_utc'
    
    Returns:
    - df_interval: DataFrame chứa các cột:
        - value: giá trị được giữ nguyên trong khoảng thời gian
        - segment: số thứ tự đoạn
        - start_time: thời gian bắt đầu đoạn
        - end_time: thời gian kết thúc đoạn
        - count: số dòng trong đoạn đó
    """
    df = df.copy()

    # Đảm bảo time_utc là datetime và sort theo thời gian
    df['time_utc'] = pd.to_datetime(df['time_utc'])
    df = df.sort_values('time_utc').reset_index(drop=True)

    # Đánh dấu điểm value thay đổi
    df['value_shift'] = df['value'].shift()
    df['new_segment'] = df['value'] != df['value_shift']

    # Đánh số các segment
    df['segment'] = df['new_segment'].cumsum()

    # Nhóm lại theo từng đoạn value giữ nguyên
    df_interval = df.groupby(['value', 'segment']).agg(
        start_time=('time_utc', 'min'),
        end_time=('time_utc', 'max'),
        count=('time_utc', 'count')
    ).reset_index()

    # Sắp xếp kết quả theo start_time
    df_interval = df_interval.sort_values('start_time').reset_index(drop=True)

    return df_interval

# %%
def prepare_cluster_interval(
    run_id,
    cluster_nr,
    
):

    # get the raw training dataset info
    saved_result, nr_clusters = get_value(run_id=run_id, keys=[
                                        "saved result destination",
                                        "n_clusters"])

    # read saved clustered result
    df = pd.read_parquet(saved_result)
    df = df[df["speed_cluster"]==cluster_nr]
    # df.shape

    df_intervals = detect_value_intervals(df)

    return run_id, saved_result, nr_clusters, df.shape, df_intervals

# %%
def filter_by_time_intervals(df_new: pd.DataFrame, df_interval: pd.DataFrame) -> pd.DataFrame:
    """
    Parameters:
    - df_new: DataFrame chứa cột 'time_utc'
    - df_interval: DataFrame chứa 'start_time' và 'end_time'

    Returns:
    - df_filtered: DataFrame đã lọc
    """
    df_new = df_new.copy()
    df_new['time_utc'] = pd.to_datetime(df_new['time_utc'])

    matched_rows = []

    for _, row in df_interval.iterrows():
        start = row['start_time']
        end = row['end_time']

        matched = df_new[
            (df_new['time_utc'] >= start) &
            (df_new['time_utc'] <= end)
        ]
        matched_rows.append(matched)

    # Gộp kết quả
    if matched_rows:
        df_filtered = pd.concat(matched_rows, ignore_index=True).drop_duplicates()
    else:
        df_filtered = pd.DataFrame(columns=df_new.columns)

    return df_filtered

# %%
# not being used jet
def prepare_analog_filtered_interval(
    df_intervals,
    tag_analog
):
    # get the run name
    run_names = [f"Transforming_{tag_analog}_{date_folder}" for date_folder in date_folders]
    print(run_names)
    # get filepath from run name - to understand which monthly dataset covered this training set
    filepaths = [get_param(
        experiment_name=experiment_name_RegularInterval,
        experiment_run=run_name,
        keyword="destination_parquet_file",
    ) for run_name in run_names]
    print(filepaths)
    # df_analog = read_df(lst_training_paths=filepaths)
    # print(df_analog.shape)
    # # filter analog input with speed cluster range
    # df_filtered = filter_by_time_intervals(df_new=df_analog, df_interval=df_intervals)

    # return run_names, filepaths, df_analog.shape, df_filtered

# %%
def shingle(data, shingle_size=10):
    # Chuyển DataFrame hoặc Series thành NumPy array nếu cần
    if isinstance(data, pd.Series) or isinstance(data, pd.DataFrame):
        data = data.values.flatten()
    
    num_data = len(data)
    
    # Kiểm tra nếu dữ liệu quá ít so với shingle_size
    if num_data < shingle_size:
        raise ValueError(f"Dữ liệu quá nhỏ ({num_data} điểm), cần ít nhất {shingle_size} điểm.")
    print("num data and shingle size:", num_data, shingle_size)
    # Tạo ma trận sliding window
    shingled_data = np.array([data[i : i + shingle_size] for i in range(num_data - shingle_size + 1)])
    
    # Chuyển NumPy array thành DataFrame với tên cột rõ ràng
    column_names = [f"feature_{i}" for i in range(shingle_size)]
    df_shingled = pd.DataFrame(shingled_data, columns=column_names)
    
    return df_shingled

# %%
# save to ...
def save_dataframe_to_s3_in_batches(
    df: pd.DataFrame, 
    s3_path_prefix: str, 
    header,
    batch_size: int = 100000,
):
    """
    Save a DataFrame to S3 in multiple CSV files, each with a batch of rows.

    Parameters:
    - df: DataFrame to save
    - s3_path_prefix: Full S3 path prefix (e.g. "s3://bucket/folder1/folder2/")
    - batch_size: Number of rows per file
    """
    import tempfile
    import s3fs

    # Tách phần bucket và prefix từ s3_path_prefix
    if not s3_path_prefix.endswith('/'):
        s3_path_prefix += '/'
    
    # Dùng s3fs để save file trực tiếp lên S3
    fs = s3fs.S3FileSystem()

    total_rows = len(df)
    total_batches = (total_rows + batch_size - 1) // batch_size

    for i in range(total_batches):
        batch_df = df[i * batch_size: (i + 1) * batch_size]
        file_name = f"part_{i:04d}.csv"
        full_s3_path = os.path.join(s3_path_prefix, file_name)

        # Save lên S3
        with fs.open(full_s3_path, 'w') as f:
            batch_df.to_csv(f, index=False, header=header)
        print(f"Saved batch {i+1}/{total_batches} to {full_s3_path}")

# %%
def training_model(s3_input_train, output_path, feature_dim, num_samples_per_tree, num_trees):
    # Lấy container mới nhất của Random Cut Forest trên SageMaker
    rcf_container = sagemaker.image_uris.retrieve("randomcutforest", region)

    # Cấu hình SageMaker Estimator
    rcf_estimator = Estimator(
        image_uri=rcf_container,
        role=role,
        instance_count=2,  # if huge amount of data, increase to 2-3 instance
        instance_type="ml.m5.xlarge",
        output_path=output_path,
        sagemaker_session=sagemaker_session,
        enable_network_isolation=True,
    )

    # **Thêm thông số training: feature_dim = 4**
    rcf_estimator.set_hyperparameters(
        # shingle_size=10,
        feature_dim=feature_dim,  # Số lượng cột đặc trưng
        num_samples_per_tree=num_samples_per_tree,  
        num_trees=num_trees  
    )

    # Định nghĩa dữ liệu đầu vào với "ShardedByS3Key"
    train_input = TrainingInput(
        s3_input_train,
        distribution="ShardedByS3Key",  # Chia dữ liệu theo file S3
        content_type="text/csv",
        input_mode="Pipe",  # Dùng Pipe Mode để stream data từ S3
    )

    # Train model
    rcf_estimator.fit({"train": train_input}, wait=True)

    # model info
    model_path = rcf_estimator.model_data

    
    return rcf_estimator, model_path

# %% [markdown]
# #### params

# %%
# motor = "DWA"
# motor = "DWB"
# motor = "DWC"
# motors

# %%
lst_run_id = [
    "783994e1b9304cf8b9eaaf1e6a16e8c9",
    "997aac8f6ea5461f9dc836e1a7987976",
    "d3586df2258b430998ec7f0d88822418"
    # "d3586df2258b430998ec7f0d88822418",
    # "997aac8f6ea5461f9dc836e1a7987976",
]

# %%
# tag_name_analog

# %%
# DWA
tag_name_analog = [
    "DWA_DSU_DC_VOLTAGE",
    "AUXILIARY_HPU_AI_PRESSURE_VALUE"
    # "...",
    # "..."
]

# %% [markdown]
# ### read total cluster and write down info to .csv file

# %%
# for run_id in lst_run_id:
#     print(get_value(run_id=run_id, keys=["n_clusters"]))

# %%
rows = []
for run_id in lst_run_id:
    n_clusters = int(get_value(run_id=run_id, keys=["n_clusters"])[0])
    for cluster_nr in range(1, n_clusters + 1):
        rows.append({"run_id": run_id, "cluster_nr": cluster_nr})
rows
# Out:
# [{'run_id': '783994e1b9304cf8b9eaaf1e6a16e8c9', 'cluster_nr': 1},
#  {'run_id': '783994e1b9304cf8b9eaaf1e6a16e8c9', 'cluster_nr': 2},
#  {'run_id': '783994e1b9304cf8b9eaaf1e6a16e8c9', 'cluster_nr': 3},
#  {'run_id': '783994e1b9304cf8b9eaaf1e6a16e8c9', 'cluster_nr': 4},
#  {'run_id': '783994e1b9304cf8b9eaaf1e6a16e8c9', 'cluster_nr': 5},
#  {'run_id': '997aac8f6ea5461f9dc836e1a7987976', 'cluster_nr': 1},
#  {'run_id': '997aac8f6ea5461f9dc836e1a7987976', 'cluster_nr': 2},
#  {'run_id': '997aac8f6ea5461f9dc836e1a7987976', 'cluster_nr': 3},
#  {'run_id': '997aac8f6ea5461f9dc836e1a7987976', 'cluster_nr': 4},
#  {'run_id': '997aac8f6ea5461f9dc836e1a7987976', 'cluster_nr': 5},
#  {'run_id': 'd3586df2258b430998ec7f0d88822418', 'cluster_nr': 1},
#  {'run_id': 'd3586df2258b430998ec7f0d88822418', 'cluster_nr': 2},
#  {'run_id': 'd3586df2258b430998ec7f0d88822418', 'cluster_nr': 3},
#  {'run_id': 'd3586df2258b430998ec7f0d88822418', 'cluster_nr': 4},
#  {'run_id': 'd3586df2258b430998ec7f0d88822418', 'cluster_nr': 5}]

# %%
# Tạo DataFrame và lưu ra file
df = pd.DataFrame(rows)
df.head()
# Out:
#                              run_id  cluster_nr
# 0  783994e1b9304cf8b9eaaf1e6a16e8c9           1
# 1  783994e1b9304cf8b9eaaf1e6a16e8c9           2
# 2  783994e1b9304cf8b9eaaf1e6a16e8c9           3
# 3  783994e1b9304cf8b9eaaf1e6a16e8c9           4
# 4  783994e1b9304cf8b9eaaf1e6a16e8c9           5

# %% [markdown]
# ##### save the run_id and mapping cluster number

# %%
df.to_csv("cluster_by_runID", index=False)

# %%
df.to_csv("cluster_by_runID.csv", index=False)

# %%
df.shape
# Out:
# (15, 2)

# %% [markdown]
# ### read info from csv file
#
#
# After edit the "cluster_by_runID" file, run the following script to train the RCF models for each run_id - cluster in those file

# %%
filepath = "cluster_by_runID"

# %%
df = pd.read_csv(filepath)
df.head()
# Out:
#                              run_id  cluster_nr
# 0  783994e1b9304cf8b9eaaf1e6a16e8c9           1
# 1  783994e1b9304cf8b9eaaf1e6a16e8c9           2
# 2  783994e1b9304cf8b9eaaf1e6a16e8c9           3
# 3  d3586df2258b430998ec7f0d88822418           3
# 4  d3586df2258b430998ec7f0d88822418           4

# %%
df.shape
# Out:
# (6, 2)

# %% [markdown]
# ### training for all run_id and cluster number

# %%
for i in range(len(df)):
    run_id = df.iloc[i]["run_id"]
    cluster_nr = df.iloc[i]["cluster_nr"]

    for tag_analog in tag_name_analog:
        print(run_id, cluster_nr, tag_analog)

        # 1. Prepare paths and parameters
        current_time = get_current_timestamp_string()
        s3_input_filtered = f"s3://s3-assetcare-bucket/features_store/training_data/read_to_evaluated/{tag_analog}_{current_time}/"
        s3_input_scored = f"s3://s3-assetcare-bucket/features_store/training_data/read_to_scored/{tag_analog}_{current_time}/"
        s3_input_train = f"s3://s3-assetcare-bucket/features_store/training_data/read_to_train/{tag_analog}_{current_time}/"
        output_path = f"s3://s3-assetcare-bucket/features_store/models/{tag_analog}_{current_time}/"

        # 2. Get cluster intervals and metadata
        _, saved_result, nr_clusters, df_shape, df_intervals = prepare_cluster_interval(
            run_id=run_id,
            cluster_nr=cluster_nr,
        )

        # 3. Build run names and file paths
        run_names = [f"Transforming_{tag_analog}_{date_folder}" for date_folder in date_folders]
        filepaths = [get_param(
            experiment_name=experiment_name_RegularInterval,
            experiment_run=run_name,
            keyword="destination_parquet_file",
        ) for run_name in run_names]

        # 4. Read and filter analog data
        df_analog = read_df(lst_training_paths=filepaths)
        df_filtered = filter_by_time_intervals(df_new=df_analog, df_interval=df_intervals)
        # save filtered data to get evaluation later
        save_dataframe_to_s3_in_batches(df=df_filtered, s3_path_prefix=s3_input_filtered, header=False)
        
        print(df_filtered.shape)
        gc.collect()

        # 5. Time-based feature engineering
        df_filtered.sort_values(by='time_utc')
        df_filtered['time_utc'] = pd.to_datetime(df_filtered['time_utc'])
        df_filtered['time_diff'] = df_filtered['time_utc'].diff().dt.total_seconds()

        average_time_diff = round(df_filtered['time_diff'].mean(), 0)
        if pd.isna(average_time_diff):
            average_time_diff = 10

        shingle_size = int(average_time_diff)

        # 6. Check if the dataset is large enough for shingling
        if len(df_filtered["value"]) <= shingle_size:
            print(f"SKIPPING: {tag_analog} cluster {cluster_nr} - not enough data for shingling (len={len(df_filtered['value'])}, required={shingle_size})")
            with mlflow.start_run(run_name=f"{tag_analog}_cluster-{cluster_nr}"):
                mlflow.log_param("Speed dataset", run_id)
                mlflow.log_param("Analog Tag name", tag_analog)
                mlflow.log_param("Cluster Nr", cluster_nr)
                mlflow.log_param("Reason", "Not enough data for shingling")
                mlflow.log_param("Data length", len(df_filtered["value"]))
                mlflow.log_param("Required shingle size", shingle_size)
            continue  # Skip training and full logging

        # 7. Create shingled dataset
        shingled_df = shingle(df_filtered["value"], shingle_size=shingle_size)
        shingled_df = shingled_df[sorted(shingled_df.columns, key=lambda x: int(x.split("_")[1]), reverse=True)]
        shingled_df = shingled_df.astype(np.float32).round(10)

        # 8. Save datasets to S3 for inference and training
        save_dataframe_to_s3_in_batches(df=shingled_df, s3_path_prefix=s3_input_scored, header=False)

        shingled_df["scores"] = 0
        shingled_df = shingled_df.astype(np.float32).round(10)
        save_dataframe_to_s3_in_batches(df=shingled_df, s3_path_prefix=s3_input_train, header=False)

        print(tag_analog)

        # 9. Train the RCF model
        rcf_estimator, model_path = training_model(
            s3_input_train=s3_input_train,
            output_path=output_path,
            feature_dim=shingle_size,
            num_samples_per_tree=1024,
            num_trees=300
        )
        print("========================")

        # 10. Log model metadata to MLflow
        with mlflow.start_run(run_name=f"{tag_analog}_cluster-{cluster_nr}"):
            mlflow.log_param("Speed dataset", run_id)
            mlflow.log_param("Analog Tag name", tag_analog)
            mlflow.log_param("Cluster Nr", cluster_nr)
            mlflow.log_param("saved_result", saved_result)
            mlflow.log_param("df_shape", df_shape)
            mlflow.log_param("df_intervals_shape", df_intervals.shape)
            mlflow.log_param("run_names", run_names)
            mlflow.log_param("filepaths", run_names)
            mlflow.log_param("Average time different", average_time_diff)
            mlflow.log_param("Shingled size", shingled_df.shape)
            mlflow.log_param("Dataset path: S3 Input Scored", s3_input_scored)
            mlflow.log_param("Dataset path: S3 Input Train", s3_input_train)
            mlflow.log_param("Dataset path: S3 Input Evaluation", s3_input_filtered)
            mlflow.log_param("Model Path", model_path)
            mlflow.log_param("Output Path", output_path)
# Out:
# 783994e1b9304cf8b9eaaf1e6a16e8c9 5 DWA_DSU_DC_VOLTAGE
# (0, 2)
# SKIPPING: DWA_DSU_DC_VOLTAGE cluster 5 - not enough data for shingling (len=0, required=10)
# 🏃 View run DWA_DSU_DC_VOLTAGE_cluster-5 at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20/runs/319749096d62498a8cbe3689c9b15bfe
# 🧪 View experiment at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20
# 783994e1b9304cf8b9eaaf1e6a16e8c9 5 AUXILIARY_HPU_AI_PRESSURE_VALUE
# (0, 2)
# SKIPPING: AUXILIARY_HPU_AI_PRESSURE_VALUE cluster 5 - not enough data for shingling (len=0, required=10)
# 🏃 View run AUXILIARY_HPU_AI_PRESSURE_VALUE_cluster-5 at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20/runs/b123b7b113df4df68dd305a33fb66f19
# 🧪 View experiment at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20
# 997aac8f6ea5461f9dc836e1a7987976 1 DWA_DSU_DC_VOLTAGE
# Saved batch 1/1 to s3://s3-assetcare-bucket/features_store/training_data/read_to_evaluated/DWA_DSU_DC_VOLTAGE_20250509_015330/part_0000.csv
# (4133, 2)
# num data and shingle size: 4133 137
# Saved batch 1/1 to s3://s3-assetcare-bucket/features_store/training_data/read_to_scored/DWA_DSU_DC_VOLTAGE_20250509_015330/part_0000.csv
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: randomcutforest-2025-05-09-01-53-57-606
# Saved batch 1/1 to s3://s3-assetcare-bucket/features_store/training_data/read_to_train/DWA_DSU_DC_VOLTAGE_20250509_015330/part_0000.csv
# DWA_DSU_DC_VOLTAGE
# 2025-05-09 01:54:02 Starting - Starting the training job...
# 2025-05-09 01:54:18 Starting - Preparing the instances for training...
# 2025-05-09 01:54:57 Downloading - Downloading the training image............
# 2025-05-09 01:56:58 Training - Training image download completed. Training in progress...Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [05/09/2025 01:57:11 INFO 140191653799744] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [05/09/2025 01:57:11 INFO 140191653799744] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '137', 'num_samples_per_tree': '1024', 'num_trees': '300'}
# [05/09/2025 01:57:11 INFO 140191653799744] Final configuration: {'num_samples_per_tree': '1024', 'num_trees': '300', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '137'}
# [05/09/2025 01:57:11 WARNING 140191653799744] Loggers have already been setup.
# [05/09/2025 01:57:11 INFO 140191653799744] Launching parameter server for role server
# [05/09/2025 01:57:11 INFO 140191653799744] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-2', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/09/2025 01:57:11 INFO 140191653799744] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-2', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '172.16.92.72', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [05/09/2025 01:57:11 INFO 140191653799744] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-2', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '172.16.92.72', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# Process 34 is a shell:server.
# Process 7 is a worker.
# [05/09/2025 01:57:11 INFO 140191653799744] Using default worker.
# [05/09/2025 01:57:11 INFO 140191653799744] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/09/2025 01:57:11 INFO 140191653799744] Checkpoint loading and saving are disabled.
# [05/09/2025 01:57:11 INFO 140191653799744] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [2025-05-09 01:57:11.208] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 64, "num_examples": 0, "num_bytes": 0}
# [05/09/2025 01:57:11 INFO 140191653799744] Verifying hyperparamemters...
# [05/09/2025 01:57:11 INFO 140191653799744] Hyperparameters are correct.
# [05/09/2025 01:57:11 INFO 140191653799744] Validating that feature_dim agrees with dimensions in training data...
# [05/09/2025 01:57:11 INFO 140191653799744] feature_dim is correct.
# [05/09/2025 01:57:11 INFO 140191653799744] Validating memory limits...
# [05/09/2025 01:57:11 INFO 140191653799744] Available memory in bytes: 14294102016
# [05/09/2025 01:57:11 INFO 140191653799744] Estimated sample size in bytes: 336691200
# [05/09/2025 01:57:11 INFO 140191653799744] Estimated memory needed to build the forest in bytes: 1683456000
# [05/09/2025 01:57:11 INFO 140191653799744] Memory limits validated.
# [05/09/2025 01:57:11 INFO 140191653799744] Starting cluster sharing facilities...
# [05/09/2025 01:57:11 INFO 140189176190720] concurrency model: async
# [05/09/2025 01:57:11 INFO 140191653799744] Create Store: dist_async
# [05/09/2025 01:57:11 INFO 140189176190720] masquerade (NAT) address: None
# [05/09/2025 01:57:11 INFO 140189176190720] passive ports: None
# [05/09/2025 01:57:11 INFO 140189176190720] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# [05/09/2025 01:57:11 INFO 140350839101248] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [05/09/2025 01:57:11 INFO 140350839101248] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '137', 'num_samples_per_tree': '1024', 'num_trees': '300'}
# [05/09/2025 01:57:11 INFO 140350839101248] Final configuration: {'num_samples_per_tree': '1024', 'num_trees': '300', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '137'}
# [05/09/2025 01:57:11 WARNING 140350839101248] Loggers have already been setup.
# [05/09/2025 01:57:11 INFO 140350839101248] Launching parameter server for role scheduler
# [05/09/2025 01:57:11 INFO 140350839101248] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-1', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/09/2025 01:57:11 INFO 140350839101248] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-1', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '172.16.92.72', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [05/09/2025 01:57:11 INFO 140350839101248] Launching parameter server for role server
# [05/09/2025 01:57:11 INFO 140350839101248] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-1', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/09/2025 01:57:11 INFO 140350839101248] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-1', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '172.16.92.72', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [05/09/2025 01:57:11 INFO 140350839101248] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-1', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-53-57-606', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-53-57-606', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '172.16.92.72', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# Process 34 is a shell:scheduler.
# Process 43 is a shell:server.
# Process 7 is a worker.
# [05/09/2025 01:57:11 INFO 140350839101248] Using default worker.
# [05/09/2025 01:57:11 INFO 140350839101248] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/09/2025 01:57:11 INFO 140350839101248] Checkpoint loading and saving are disabled.
# [05/09/2025 01:57:11 INFO 140350839101248] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [05/09/2025 01:57:11 INFO 140350839101248] Verifying hyperparamemters...
# [05/09/2025 01:57:11 INFO 140350839101248] Hyperparameters are correct.
# [05/09/2025 01:57:11 INFO 140350839101248] Validating that feature_dim agrees with dimensions in training data...
# [05/09/2025 01:57:11 INFO 140350839101248] feature_dim is correct.
# [05/09/2025 01:57:11 INFO 140350839101248] Validating memory limits...
# [05/09/2025 01:57:11 INFO 140350839101248] Available memory in bytes: 14282432512
# [05/09/2025 01:57:11 INFO 140350839101248] Estimated sample size in bytes: 336691200
# [05/09/2025 01:57:11 INFO 140350839101248] Estimated memory needed to build the forest in bytes: 1683456000
# [05/09/2025 01:57:11 INFO 140350839101248] Memory limits validated.
# [05/09/2025 01:57:11 INFO 140350839101248] Starting cluster sharing facilities...
# [05/09/2025 01:57:11 INFO 140348282091264] concurrency model: async
# [05/09/2025 01:57:11 INFO 140350839101248] Create Store: dist_async
# [05/09/2025 01:57:11 INFO 140348282091264] masquerade (NAT) address: None
# [05/09/2025 01:57:11 INFO 140348282091264] passive ports: None
# [05/09/2025 01:57:11 INFO 140348282091264] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# [05/09/2025 01:57:12 INFO 140350839101248] Cluster sharing facilities started.
# [05/09/2025 01:57:12 INFO 140350839101248] Verifying all workers are accessible...
# [05/09/2025 01:57:12 INFO 140348282091264] 172.16.64.239:44986-[] FTP session opened (connect)
# [05/09/2025 01:57:12 INFO 140348282091264] 172.16.64.239:44986-[anonymous] USER 'anonymous' logged in.
# [05/09/2025 01:57:12 INFO 140350839101248] All workers accessible.
# [05/09/2025 01:57:12 INFO 140348282091264] 172.16.64.239:44986-[anonymous] FTP session closed (disconnect).
# [05/09/2025 01:57:12 INFO 140350839101248] Initializing Sampler...
# [05/09/2025 01:57:12 INFO 140350839101248] Sampler correctly initialized.
# #metrics {"StartTime": 1746755831.212616, "EndTime": 1746755832.445294, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1209.7580432891846, "count": 1, "min": 1209.7580432891846, "max": 1209.7580432891846}}}
# #metrics {"StartTime": 1746755832.4454272, "EndTime": 1746755832.4454608, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2025-05-09 01:57:12.445] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1232, "num_examples": 1, "num_bytes": 0}
# [05/09/2025 01:57:12 INFO 140350839101248] Sampling training data...
# [05/09/2025 01:57:12 INFO 140191653799744] Cluster sharing facilities started.
# [05/09/2025 01:57:12 INFO 140191653799744] Verifying all workers are accessible...
# [05/09/2025 01:57:12 INFO 140189176190720] 172.16.92.72:39416-[] FTP session opened (connect)
# [05/09/2025 01:57:12 INFO 140189176190720] 172.16.92.72:39416-[anonymous] USER 'anonymous' logged in.
# [05/09/2025 01:57:12 INFO 140191653799744] All workers accessible.
# [05/09/2025 01:57:12 INFO 140191653799744] Initializing Sampler...
# [05/09/2025 01:57:12 INFO 140189176190720] 172.16.92.72:39416-[anonymous] FTP session closed (disconnect).
# [05/09/2025 01:57:12 INFO 140191653799744] Sampler correctly initialized.
# #metrics {"StartTime": 1746755831.1433191, "EndTime": 1746755832.4452312, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1236.1457347869873, "count": 1, "min": 1236.1457347869873, "max": 1236.1457347869873}}}
# #metrics {"StartTime": 1746755832.4453814, "EndTime": 1746755832.4454207, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/09/2025 01:57:12 INFO 140191653799744] Sampling training data...
# [05/09/2025 01:57:12 INFO 140191653799744] Sampling training data completed.
# #metrics {"StartTime": 1746755832.4453318, "EndTime": 1746755832.4465182, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 0.9021759033203125, "count": 1, "min": 0.9021759033203125, "max": 0.9021759033203125}}}
# [05/09/2025 01:57:12 INFO 140191653799744] Early stop condition met. Stopping training.
# [05/09/2025 01:57:12 INFO 140191653799744] #progress_metric: host=algo-2, completed 100 % epochs
# #metrics {"StartTime": 1746755832.445596, "EndTime": 1746755832.4468389, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2025-05-09 01:57:13.458] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 1012, "num_examples": 4, "num_bytes": 0}
# [05/09/2025 01:57:13 INFO 140350839101248] Sampling training data completed.
# #metrics {"StartTime": 1746755832.4453807, "EndTime": 1746755833.4631796, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 1017.4193382263184, "count": 1, "min": 1017.4193382263184, "max": 1017.4193382263184}}}
# [05/09/2025 01:57:13 INFO 140350839101248] Early stop condition met. Stopping training.
# [05/09/2025 01:57:13 INFO 140350839101248] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1746755832.445732, "EndTime": 1746755833.4634933, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3997.0, "count": 1, "min": 3997, "max": 3997}, "Total Batches Seen": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Max Records Seen Between Resets": {"sum": 3997.0, "count": 1, "min": 3997, "max": 3997}, "Max Batches Seen Between Resets": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 3997.0, "count": 1, "min": 3997, "max": 3997}, "Number of Batches Since Last Reset": {"sum": 4.0, "count": 1, "min": 4, "max": 4}}}
# [05/09/2025 01:57:13 INFO 140350839101248] #throughput_metric: host=algo-1, train throughput=3926.800192819127 records/second
# [05/09/2025 01:57:13 INFO 140350839101248] Master node: building Random Cut Forest...
# [05/09/2025 01:57:13 INFO 140350839101248] Gathering samples...
# [05/09/2025 01:57:13 INFO 140350839101248] 3997 samples gathered
# [05/09/2025 01:57:13 INFO 140350839101248] Building Random Cut Forest...
# [05/09/2025 01:57:13 INFO 140350839101248] Random Cut Forest built:
# ForestInfo{num_trees: 300, num_samples_in_forest: 3900, num_samples_per_tree: 13, sample_dim: 137, shingle_size: 1, trees_num_nodes: [25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, ], trees_depth: [6, 8, 6, 7, 7, 7, 8, 6, 6, 8, 6, 6, 9, 6, 6, 7, 6, 9, 7, 7, 6, 7, 7, 7, 8, 11, 8, 7, 8, 7, 7, 8, 7, 7, 7, 8, 10, 6, 7, 6, 6, 8, 7, 7, 9, 7, 6, 7, 6, 8, 6, 7, 7, 6, 8, 7, 8, 7, 7, 9, 7, 8, 8, 6, 7, 6, 5, 7, 7, 8, 6, 6, 6, 8, 6, 7, 6, 8, 7, 7, 8, 8, 7, 9, 7, 7, 8, 7, 7, 6, 7, 7, 6, 6, 7, 6, 8, 7, 7, 7, 7, 7, 7, 7, 7, 6, 7, 8, 7, 7, 7, 8, 8, 6, 7, 7, 7, 7, 6, 7, 7, 8, 7, 7, 9, 7, 8, 7, 9, 8, 8, 6, 6, 7, 6, 8, 8, 8, 6, 7, 8, 9, 7, 8, 8, 7, 9, 9, 7, 7, 7, 7, 8, 6, 8, 8, 7, 8, 6, 7, 7, 8, 8, 7, 8, 6, 8, 6, 6, 6, 6, 8, 6, 8, 6, 7, 8, 6, 7, 8, 8, 8, 7, 7, 6, 7, 8, 10, 8, 9, 6, 8, 7, 7, 8, 6, 6, 6, 8, 8, 6, 6, 9, 7, 7, 7, 8, 8, 7, 7, 7, 6, 6, 7, 7, 6, 8, 7, 7, 5, 6, 6, 6, 8, 7, 6, 8, 7, 7, 7, 8, 9, 6, 6, 8, 7, 6, 7, 8, 7, 7, 8, 6, 6, 8, 8, 7, 8, 6, 6, 7, 7, 6, 6, 6, 6, 8, 6, 8, 7, 9, 7, 8, 7, 9, 10, 8, 10, 7, 8, 7, 7, 6, 9, 7, 7, 7, 7, 7, 7, 7, 8, 7, 7, 6, 9, 7, 7, 7, 6, 7, 7, 6, 9, 8, 9, 7, 7, 7, 7, ], max_num_nodes: 25, min_num_nodes: 25, avg_num_nodes: 25, max_tree_depth: 11, min_tree_depth: 5, avg_tree_depth: 7, mem_size: 17102448}
# #metrics {"StartTime": 1746755833.4632616, "EndTime": 1746755833.4998724, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 27.487516403198242, "count": 1, "min": 27.487516403198242, "max": 27.487516403198242}, "model.bytes": {"sum": 17102448.0, "count": 1, "min": 17102448, "max": 17102448}, "finalize.time": {"sum": 35.8278751373291, "count": 1, "min": 35.8278751373291, "max": 35.8278751373291}}}
# [05/09/2025 01:57:13 INFO 140350839101248] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1746755833.4999616, "EndTime": 1746755833.6905258, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 190.5214786529541, "count": 1, "min": 190.5214786529541, "max": 190.5214786529541}}}
# [05/09/2025 01:57:13 INFO 140350839101248] Test data is not provided.
# #metrics {"StartTime": 1746755833.6905847, "EndTime": 1746755833.692694, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 21.736860275268555, "count": 1, "min": 21.736860275268555, "max": 21.736860275268555}, "totaltime": {"sum": 2507.1628093719482, "count": 1, "min": 2507.1628093719482, "max": 2507.1628093719482}}}
# [05/09/2025 01:57:13 INFO 140189176190720] 172.16.92.72:39422-[] FTP session opened (connect)
# [05/09/2025 01:57:13 INFO 140189176190720] 172.16.92.72:39422-[anonymous] USER 'anonymous' logged in.
# [05/09/2025 01:57:13 INFO 140189176190720] 172.16.92.72:39422-[anonymous] RETR /tmp/data completed=1 bytes=72 seconds=0.0
# [05/09/2025 01:57:13 INFO 140189176190720] 172.16.92.72:39422-[anonymous] FTP session closed (disconnect).
# #metrics {"StartTime": 1746755832.4466417, "EndTime": 1746755833.4998064, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"finalize.time": {"sum": 35.675048828125, "count": 1, "min": 35.675048828125, "max": 35.675048828125}}}
# [05/09/2025 01:57:13 INFO 140191653799744] Test data is not provided.
# #metrics {"StartTime": 1746755833.4998896, "EndTime": 1746755833.500243, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 17.069578170776367, "count": 1, "min": 17.069578170776367, "max": 17.069578170776367}, "totaltime": {"sum": 2378.406524658203, "count": 1, "min": 2378.406524658203, "max": 2378.406524658203}}}
#
# 2025-05-09 01:57:27 Uploading - Uploading generated training model
# 2025-05-09 01:57:27 Completed - Training job completed
# Training seconds: 340
# Billable seconds: 340
# ========================
# 🏃 View run DWA_DSU_DC_VOLTAGE_cluster-1 at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20/runs/6e9da702d6b04085b729532e93285d78
# 🧪 View experiment at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20
# 997aac8f6ea5461f9dc836e1a7987976 1 AUXILIARY_HPU_AI_PRESSURE_VALUE
# (0, 2)
# SKIPPING: AUXILIARY_HPU_AI_PRESSURE_VALUE cluster 1 - not enough data for shingling (len=0, required=10)
# 🏃 View run AUXILIARY_HPU_AI_PRESSURE_VALUE_cluster-1 at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20/runs/59d9782433ac4cd6a6e6ec9c78b8b4f3
# 🧪 View experiment at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20
# 997aac8f6ea5461f9dc836e1a7987976 2 DWA_DSU_DC_VOLTAGE
# Saved batch 1/1 to s3://s3-assetcare-bucket/features_store/training_data/read_to_evaluated/DWA_DSU_DC_VOLTAGE_20250509_015759/part_0000.csv
# (5849, 2)
# num data and shingle size: 5849 105
# Saved batch 1/1 to s3://s3-assetcare-bucket/features_store/training_data/read_to_scored/DWA_DSU_DC_VOLTAGE_20250509_015759/part_0000.csv
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: randomcutforest-2025-05-09-01-58-38-800
# Saved batch 1/1 to s3://s3-assetcare-bucket/features_store/training_data/read_to_train/DWA_DSU_DC_VOLTAGE_20250509_015759/part_0000.csv
# DWA_DSU_DC_VOLTAGE
# 2025-05-09 01:58:38 Starting - Starting the training job...
# 2025-05-09 01:59:01 Starting - Preparing the instances for training...
# 2025-05-09 01:59:39 Downloading - Downloading the training image............
# 2025-05-09 02:01:31 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [05/09/2025 02:01:41 INFO 140589865432896] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [05/09/2025 02:01:41 INFO 140589865432896] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '105', 'num_samples_per_tree': '1024', 'num_trees': '300'}
# [05/09/2025 02:01:41 INFO 140589865432896] Final configuration: {'num_samples_per_tree': '1024', 'num_trees': '300', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '105'}
# [05/09/2025 02:01:41 WARNING 140589865432896] Loggers have already been setup.
# [05/09/2025 02:01:41 INFO 140589865432896] Launching parameter server for role server
# [05/09/2025 02:01:41 INFO 140589865432896] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-2', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-58-38-800', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-58-38-800', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/09/2025 02:01:41 INFO 140589865432896] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-2', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-58-38-800', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-58-38-800', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '172.16.174.185', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [05/09/2025 02:01:41 INFO 140589865432896] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-2', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-58-38-800', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-58-38-800', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '172.16.174.185', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# Process 34 is a shell:server.
# Process 7 is a worker.
# [05/09/2025 02:01:41 INFO 140589865432896] Using default worker.
# [05/09/2025 02:01:41 INFO 140589865432896] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/09/2025 02:01:41 INFO 140589865432896] Checkpoint loading and saving are disabled.
# [05/09/2025 02:01:41 INFO 140589865432896] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [2025-05-09 02:01:41.624] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 103, "num_examples": 0, "num_bytes": 0}
# [05/09/2025 02:01:41 INFO 140589865432896] Verifying hyperparamemters...
# [05/09/2025 02:01:41 INFO 140589865432896] Hyperparameters are correct.
# [05/09/2025 02:01:41 INFO 140589865432896] Validating that feature_dim agrees with dimensions in training data...
# [05/09/2025 02:01:41 INFO 140589865432896] feature_dim is correct.
# [05/09/2025 02:01:41 INFO 140589865432896] Validating memory limits...
# [05/09/2025 02:01:41 INFO 140589865432896] Available memory in bytes: 14135558144
# [05/09/2025 02:01:41 INFO 140589865432896] Estimated sample size in bytes: 258048000
# [05/09/2025 02:01:41 INFO 140589865432896] Estimated memory needed to build the forest in bytes: 1290240000
# [05/09/2025 02:01:41 INFO 140589865432896] Memory limits validated.
# [05/09/2025 02:01:41 INFO 140589865432896] Starting cluster sharing facilities...
# [05/09/2025 02:01:41 INFO 140587387606784] concurrency model: async
# [05/09/2025 02:01:41 INFO 140589865432896] Create Store: dist_async
# [05/09/2025 02:01:41 INFO 140587387606784] masquerade (NAT) address: None
# [05/09/2025 02:01:41 INFO 140587387606784] passive ports: None
# [05/09/2025 02:01:41 INFO 140587387606784] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [05/09/2025 02:01:41 INFO 140052123432768] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [05/09/2025 02:01:41 INFO 140052123432768] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '105', 'num_samples_per_tree': '1024', 'num_trees': '300'}
# [05/09/2025 02:01:41 INFO 140052123432768] Final configuration: {'num_samples_per_tree': '1024', 'num_trees': '300', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '105'}
# [05/09/2025 02:01:41 WARNING 140052123432768] Loggers have already been setup.
# [05/09/2025 02:01:41 INFO 140052123432768] Launching parameter server for role scheduler
# [05/09/2025 02:01:41 INFO 140052123432768] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-1', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-58-38-800', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-58-38-800', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/09/2025 02:01:41 INFO 140052123432768] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'algo-1', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-09-01-58-38-800', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-southeast-1:771463264346:training-job/randomcutforest-2025-05-09-01-58-38-800', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-southeast-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '172.16.174.185', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [05/09/2025 02:01:41 INFO 140052123432768] Launching parameter server for role server
# ...
# Process 34 is a shell:server.
# Process 7 is a worker.
# [05/09/2025 02:27:34 INFO 140266364094272] Using default worker.
# [05/09/2025 02:27:34 INFO 140266364094272] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/09/2025 02:27:34 INFO 140266364094272] Checkpoint loading and saving are disabled.
# [05/09/2025 02:27:34 INFO 140266364094272] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [2025-05-09 02:27:34.703] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 88, "num_examples": 0, "num_bytes": 0}
# [05/09/2025 02:27:34 INFO 140266364094272] Verifying hyperparamemters...
# [05/09/2025 02:27:34 INFO 140266364094272] Hyperparameters are correct.
# [05/09/2025 02:27:34 INFO 140266364094272] Validating that feature_dim agrees with dimensions in training data...
# [05/09/2025 02:27:34 INFO 140266364094272] feature_dim is correct.
# [05/09/2025 02:27:34 INFO 140266364094272] Validating memory limits...
# [05/09/2025 02:27:34 INFO 140266364094272] Available memory in bytes: 14475083776
# [05/09/2025 02:27:34 INFO 140266364094272] Estimated sample size in bytes: 346521600
# [05/09/2025 02:27:34 INFO 140266364094272] Estimated memory needed to build the forest in bytes: 1732608000
# [05/09/2025 02:27:34 INFO 140266364094272] Memory limits validated.
# [05/09/2025 02:27:34 INFO 140266364094272] Starting cluster sharing facilities...
# [05/09/2025 02:27:34 INFO 140263813011200] concurrency model: async
# [05/09/2025 02:27:34 INFO 140266364094272] Create Store: dist_async
# [05/09/2025 02:27:34 INFO 140263813011200] masquerade (NAT) address: None
# [05/09/2025 02:27:34 INFO 140263813011200] passive ports: None
# [05/09/2025 02:27:34 INFO 140263813011200] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# [05/09/2025 02:27:34 INFO 139870005184320] Verifying hyperparamemters...
# [05/09/2025 02:27:34 INFO 139870005184320] Hyperparameters are correct.
# [05/09/2025 02:27:34 INFO 139870005184320] Validating that feature_dim agrees with dimensions in training data...
# [05/09/2025 02:27:34 INFO 139870005184320] feature_dim is correct.
# [05/09/2025 02:27:34 INFO 139870005184320] Validating memory limits...
# [05/09/2025 02:27:34 INFO 139870005184320] Available memory in bytes: 14462373888
# [05/09/2025 02:27:34 INFO 139870005184320] Estimated sample size in bytes: 346521600
# [05/09/2025 02:27:34 INFO 139870005184320] Estimated memory needed to build the forest in bytes: 1732608000
# [05/09/2025 02:27:34 INFO 139870005184320] Memory limits validated.
# [05/09/2025 02:27:34 INFO 139870005184320] Starting cluster sharing facilities...
# [05/09/2025 02:27:34 INFO 139867447080704] concurrency model: async
# [05/09/2025 02:27:34 INFO 139870005184320] Create Store: dist_async
# [05/09/2025 02:27:34 INFO 139867447080704] masquerade (NAT) address: None
# [05/09/2025 02:27:34 INFO 139867447080704] passive ports: None
# [05/09/2025 02:27:34 INFO 139867447080704] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# [05/09/2025 02:27:35 INFO 140266364094272] Cluster sharing facilities started.
# [05/09/2025 02:27:35 INFO 140266364094272] Verifying all workers are accessible...
# [05/09/2025 02:27:35 INFO 140263813011200] 172.16.248.123:59924-[] FTP session opened (connect)
# [05/09/2025 02:27:35 INFO 140263813011200] 172.16.248.123:59924-[anonymous] USER 'anonymous' logged in.
# [05/09/2025 02:27:35 INFO 140266364094272] All workers accessible.
# [05/09/2025 02:27:35 INFO 140266364094272] Initializing Sampler...
# [05/09/2025 02:27:35 INFO 140263813011200] 172.16.248.123:59924-[anonymous] FTP session closed (disconnect).
# [05/09/2025 02:27:35 INFO 140266364094272] Sampler correctly initialized.
# #metrics {"StartTime": 1746757654.6150231, "EndTime": 1746757655.5953875, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 891.2274837493896, "count": 1, "min": 891.2274837493896, "max": 891.2274837493896}}}
# #metrics {"StartTime": 1746757655.595523, "EndTime": 1746757655.5955555, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/09/2025 02:27:35 INFO 140266364094272] Sampling training data...
# [05/09/2025 02:27:35 INFO 140266364094272] Sampling training data completed.
# #metrics {"StartTime": 1746757655.5954764, "EndTime": 1746757655.5965075, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 0.7832050323486328, "count": 1, "min": 0.7832050323486328, "max": 0.7832050323486328}}}
# [05/09/2025 02:27:35 INFO 140266364094272] Early stop condition met. Stopping training.
# [05/09/2025 02:27:35 INFO 140266364094272] #progress_metric: host=algo-2, completed 100 % epochs
# #metrics {"StartTime": 1746757655.5957062, "EndTime": 1746757655.596794, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/09/2025 02:27:35 INFO 139870005184320] Cluster sharing facilities started.
# [05/09/2025 02:27:35 INFO 139870005184320] Verifying all workers are accessible...
# [05/09/2025 02:27:35 INFO 139867447080704] 172.16.213.5:41726-[] FTP session opened (connect)
# [05/09/2025 02:27:35 INFO 139867447080704] 172.16.213.5:41726-[anonymous] USER 'anonymous' logged in.
# [05/09/2025 02:27:35 INFO 139870005184320] All workers accessible.
# [05/09/2025 02:27:35 INFO 139870005184320] Initializing Sampler...
# [05/09/2025 02:27:35 INFO 139867447080704] 172.16.213.5:41726-[anonymous] FTP session closed (disconnect).
# [05/09/2025 02:27:35 INFO 139870005184320] Sampler correctly initialized.
# #metrics {"StartTime": 1746757654.0950375, "EndTime": 1746757655.5953953, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1482.6171398162842, "count": 1, "min": 1482.6171398162842, "max": 1482.6171398162842}}}
# #metrics {"StartTime": 1746757655.595539, "EndTime": 1746757655.5955772, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2025-05-09 02:27:35.595] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1499, "num_examples": 1, "num_bytes": 0}
# [05/09/2025 02:27:35 INFO 139870005184320] Sampling training data...
# [05/09/2025 02:27:36 INFO 140263813011200] 172.16.248.123:59928-[] FTP session opened (connect)
# [05/09/2025 02:27:36 INFO 140263813011200] 172.16.248.123:59928-[anonymous] USER 'anonymous' logged in.
# [05/09/2025 02:27:36 INFO 140263813011200] 172.16.248.123:59928-[anonymous] RETR /tmp/data completed=1 bytes=72 seconds=0.001
# [05/09/2025 02:27:36 INFO 140263813011200] 172.16.248.123:59928-[anonymous] FTP session closed (disconnect).
# #metrics {"StartTime": 1746757655.5965703, "EndTime": 1746757656.6448052, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"finalize.time": {"sum": 30.1210880279541, "count": 1, "min": 30.1210880279541, "max": 30.1210880279541}}}
# [05/09/2025 02:27:36 INFO 140266364094272] Test data is not provided.
# #metrics {"StartTime": 1746757656.6449025, "EndTime": 1746757656.6452289, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-2", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 16.115903854370117, "count": 1, "min": 16.115903854370117, "max": 16.115903854370117}, "totaltime": {"sum": 2050.203561782837, "count": 1, "min": 2050.203561782837, "max": 2050.203561782837}}}
# [2025-05-09 02:27:36.608] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 1012, "num_examples": 4, "num_bytes": 0}
# [05/09/2025 02:27:36 INFO 139870005184320] Sampling training data completed.
# #metrics {"StartTime": 1746757655.5954914, "EndTime": 1746757656.6134088, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 1017.5063610076904, "count": 1, "min": 1017.5063610076904, "max": 1017.5063610076904}}}
# [05/09/2025 02:27:36 INFO 139870005184320] Early stop condition met. Stopping training.
# [05/09/2025 02:27:36 INFO 139870005184320] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1746757655.595875, "EndTime": 1746757656.6137066, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3869.0, "count": 1, "min": 3869, "max": 3869}, "Total Batches Seen": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Max Records Seen Between Resets": {"sum": 3869.0, "count": 1, "min": 3869, "max": 3869}, "Max Batches Seen Between Resets": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 3869.0, "count": 1, "min": 3869, "max": 3869}, "Number of Batches Since Last Reset": {"sum": 4.0, "count": 1, "min": 4, "max": 4}}}
# [05/09/2025 02:27:36 INFO 139870005184320] #throughput_metric: host=algo-1, train throughput=3800.802559138385 records/second
# [05/09/2025 02:27:36 INFO 139870005184320] Master node: building Random Cut Forest...
# [05/09/2025 02:27:36 INFO 139870005184320] Gathering samples...
# [05/09/2025 02:27:36 INFO 139870005184320] 3869 samples gathered
# [05/09/2025 02:27:36 INFO 139870005184320] Building Random Cut Forest...
# [05/09/2025 02:27:36 INFO 139870005184320] Random Cut Forest built:
# ForestInfo{num_trees: 300, num_samples_in_forest: 3600, num_samples_per_tree: 12, sample_dim: 141, shingle_size: 1, trees_num_nodes: [23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, ], trees_depth: [7, 6, 5, 6, 6, 6, 8, 8, 6, 6, 6, 7, 7, 7, 6, 7, 7, 7, 7, 7, 7, 7, 8, 7, 6, 7, 6, 8, 9, 9, 7, 7, 6, 5, 7, 8, 7, 7, 6, 6, 7, 7, 7, 7, 7, 6, 8, 8, 8, 6, 8, 7, 8, 6, 7, 7, 7, 6, 7, 7, 8, 8, 7, 7, 7, 8, 6, 7, 6, 5, 6, 7, 7, 6, 7, 7, 6, 8, 6, 6, 7, 7, 7, 6, 6, 8, 8, 6, 7, 7, 10, 7, 7, 8, 6, 6, 7, 7, 7, 7, 8, 6, 7, 8, 7, 6, 7, 8, 6, 8, 6, 9, 5, 7, 6, 5, 6, 7, 6, 7, 6, 7, 7, 6, 8, 7, 9, 6, 8, 6, 7, 9, 8, 8, 9, 8, 8, 7, 8, 6, 6, 7, 6, 7, 8, 7, 9, 7, 7, 6, 9, 7, 8, 8, 7, 6, 6, 7, 10, 6, 6, 8, 7, 7, 5, 6, 6, 7, 5, 6, 6, 6, 6, 5, 8, 9, 6, 7, 7, 7, 8, 6, 7, 6, 6, 7, 6, 7, 8, 8, 10, 8, 8, 8, 8, 6, 8, 8, 7, 6, 8, 6, 7, 6, 8, 7, 7, 6, 7, 7, 8, 7, 7, 6, 8, 7, 7, 6, 8, 8, 6, 8, 7, 6, 6, 7, 8, 7, 8, 7, 7, 7, 7, 6, 7, 8, 10, 7, 7, 7, 6, 7, 8, 5, 9, 8, 8, 7, 5, 8, 7, 6, 5, 8, 6, 8, 5, 6, 6, 7, 8, 7, 7, 8, 6, 6, 6, 8, 7, 7, 8, 10, 7, 6, 8, 8, 7, 7, 8, 7, 6, 8, 7, 7, 7, 6, 7, 8, 6, 7, 7, 7, 6, 6, 8, 6, 6, 5, 6, 6, ], max_num_nodes: 23, min_num_nodes: 23, avg_num_nodes: 23, max_tree_depth: 10, min_tree_depth: 5, avg_tree_depth: 6, mem_size: 16176048}
# #metrics {"StartTime": 1746757656.613491, "EndTime": 1746757656.6448388, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 21.849870681762695, "count": 1, "min": 21.849870681762695, "max": 21.849870681762695}, "model.bytes": {"sum": 16176048.0, "count": 1, "min": 16176048, "max": 16176048}, "finalize.time": {"sum": 30.266523361206055, "count": 1, "min": 30.266523361206055, "max": 30.266523361206055}}}
# [05/09/2025 02:27:36 INFO 139870005184320] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1746757656.6449287, "EndTime": 1746757656.819199, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 174.22962188720703, "count": 1, "min": 174.22962188720703, "max": 174.22962188720703}}}
# [05/09/2025 02:27:36 INFO 139870005184320] Test data is not provided.
# #metrics {"StartTime": 1746757656.8192701, "EndTime": 1746757656.8213007, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 22.765159606933594, "count": 1, "min": 22.765159606933594, "max": 22.765159606933594}, "totaltime": {"sum": 2754.833698272705, "count": 1, "min": 2754.833698272705, "max": 2754.833698272705}}}
#
# 2025-05-09 02:27:53 Uploading - Uploading generated training model
# 2025-05-09 02:27:53 Completed - Training job completed
# Training seconds: 258
# Billable seconds: 258
# ========================
# 🏃 View run DWA_DSU_DC_VOLTAGE_cluster-2 at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20/runs/b43c964be94e44de8b60c16bc87c0ca4
# 🧪 View experiment at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20
# d3586df2258b430998ec7f0d88822418 2 AUXILIARY_HPU_AI_PRESSURE_VALUE
# (0, 2)
# SKIPPING: AUXILIARY_HPU_AI_PRESSURE_VALUE cluster 2 - not enough data for shingling (len=0, required=10)
# 🏃 View run AUXILIARY_HPU_AI_PRESSURE_VALUE_cluster-2 at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20/runs/21c01a991c4e4cf8b0701ad03ffeb29d
# 🧪 View experiment at: https://ap-southeast-1.experiments.sagemaker.aws/#/experiments/20
