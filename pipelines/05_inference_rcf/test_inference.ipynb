# %%
import pandas as pd
import numpy as np

# %%
filepath = "https://swo-ngoctran-public.s3.us-east-1.amazonaws.com/mlops/raw_data/2024-01/30/23/sample_output1.parquet"

# %%
df = pd.read_parquet(filepath)
df.shape
# Out:
# (140000, 10)

# %%
df.columns
# Out:
# Index(['historian_id', 'tag_name', 'value', 'status', 'time_utc', 'time_sing',
#        'Digital/analog', 'tag_group_name', 'source', 'units'],
#       dtype='object')

# %%
df["tag_name"].value_counts()
# Out:
# tag_name
# DWA_DSU_MAIN_AC_VOLTAGE    63592
# DWA_DSU_DC_VOLTAGE         45410
# DWA_ACTUAL_MOTOR_SPEED     14768
# DWB_ACTUAL_MOTOR_TORQUE     5971
# DWA_DSU_ACTUAL_POWER        3025
# DWA_ACTUAL_MOTOR_TORQUE     2409
# DWA_ACTUAL_POWER            2067
# DWA_INVERTER_RUNNING        1383
# DWA_ACTUAL_MOTOR_TEMP       1375
# Name: count, dtype: int64
